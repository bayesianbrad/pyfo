# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
def sigmoid(x, beta, yscale=1, xscale=0, up_shift=0):
    """
    If we set beta suitably large then we can approximate a verticla line at the discountinuity 
    representing something continous. 
    :param x: 
    :param beta: 
    :param up_shift: 
    :param scale: 
    :return: 
    """
    return yscale* (1 / (1 + np.exp(-beta*(x-xscale)))) + up_shift

# %%
def inv_sigmoid(x,beta, v_scale,x_scale=0, y_scale=0):
    """
    If we set beta suitably large then we can approximate a verticla line at the discountinuity 
    representing something continous. 
    :param x: 
    :param beta: 
    :param up_shift: 
    :param scale: 
    :return: 
    """
    return v_scale*np.exp(-np.exp(beta*(x-x_scale))) + y_scale

# %%
limit = 5
delta = 0.025
beta = [1,5,25,1000]
vscale = [10]
yscale = [4.5]

xscale = -1
x_plus = xscale + delta
x_min   = xscale - delta
delta = [0.001]
x = np.arange(-limit, limit,step=0.01)
print(len(x))
# y = inv_sigmoid(x)
fig, ax = plt.subplots()
ax.grid(True, which= 'both')
ax.tick_params(axis=u'both', which=u'both',length=0)
ax.set_xlabel('Latent')
ax.set_ylabel('function_val')
ax.tick_params(axis='x', colors='red')
ax.tick_params(axis='y', colors='red')
for i in beta:
        y = inv_sigmoid(x,i,vscale,xscale,yscale)
        # indices = np.where((x > x_min) & (x < x_plus))[0]
        # y_new = y[indices]
        # ax.plot(x[indices],y_new)
        ax.plot(x, y)
# print(indices)
# print(type(y))
# Out:
# 1000
# /Users/bradley/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:11: RuntimeWarning: overflow encountered in exp

# %%
limit = 5
x = np.arange(-limit,limit,step=0.01)
delta = 0.025
beta = [1, 2,5,100]
upshift = [4] 
yscale = [1]
xscale = [-0.5, 0.5]
fig, ax  = plt.subplots()
for i in beta:
    for j in yscale:
        for k in xscale:
            for l in upshift:
              y = sigmoid(x, i, j, k,l)
              ax.plot(x, y, label = "With beta=  {0} and shift {1}".format(i,j))
ax.grid(True, which= 'both')
ax.tick_params(axis=u'both', which=u'both',length=0)
ax.set_xlabel('Latent')
ax.set_ylabel('function_val')
ax.tick_params(axis='x', colors='red')
ax.tick_params(axis='y', colors='red')
# print(y[1:100])

# %%
limit = 5
dx = 0.1
discont = 0
x = np.linspace(-limit,limit,1000)
# print(x)
beta = [1]
upshift = [0] 
yscale = [1]
xscale = [0]
fig, ax  = plt.subplots()
for i in beta:
    for j in yscale:
        for k in xscale:
            for l in upshift:
              y = inv_sigmoid(x, i, j, k)
              ax.plot(x, y)
ax.grid(True, which= 'both')
ax.tick_params(axis=u'both', which=u'both',length=0)
ax.set_xlabel('Latent')
ax.set_ylabel('function_val')
ax.tick_params(axis='x', colors='red')
ax.tick_params(axis='y', colors='red')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-bb2d6d9509b1> in <module>()
#      13         for k in xscale:
#      14             for l in upshift:
# ---> 15               y = inv_sigmoid(x, i, j, k,l)
#      16               ax.plot(x, y)
#      17 ax.grid(True, which= 'both')
#
# TypeError: inv_sigmoid() takes from 3 to 4 positional arguments but 5 were given

# %%
import scipy.stats as ss

limit = 5
dx = 0.001
discont = 0
x = np.linspace(discont-dx,discont+dx,1000)
fig, ax  = plt.subplots()
normal = ss.multivariate_normal(mean = 0, cov = 1)
x1=  np.arange(-limit,0.01)
samples = normal.pdf(x1)
ax.plot(x1,samples)
normal2 = ss.multivariate_normal(mean=0,cov=5)
x2 = np.arange(0,limit,0.01)
samples2 = normal2.pdf(x2)
ax.plot(x2,samples2)
beta = [100]
upshift = [max] 
yscale = [0.4]
xscale = [0]
for i in beta:
    for j in yscale:
        for k in xscale:
            for l in upshift:
              y = inv_sigmoid(x, i, j, k,l)
              ax.plot(x, y)
ax.set_xlabel('Latent')
ax.set_ylabel('function_val')
ax.tick_params(axis='x', colors='red')
ax.tick_params(axis='y', colors='red')
# Out:
# [ -1.00000000e-03  -9.97997998e-04  -9.95995996e-04  -9.93993994e-04
#   -9.91991992e-04  -9.89989990e-04  -9.87987988e-04  -9.85985986e-04
#   -9.83983984e-04  -9.81981982e-04  -9.79979980e-04  -9.77977978e-04
#   -9.75975976e-04  -9.73973974e-04  -9.71971972e-04  -9.69969970e-04
#   -9.67967968e-04  -9.65965966e-04  -9.63963964e-04  -9.61961962e-04
#   -9.59959960e-04  -9.57957958e-04  -9.55955956e-04  -9.53953954e-04
#   -9.51951952e-04  -9.49949950e-04  -9.47947948e-04  -9.45945946e-04
#   -9.43943944e-04  -9.41941942e-04  -9.39939940e-04  -9.37937938e-04
#   -9.35935936e-04  -9.33933934e-04  -9.31931932e-04  -9.29929930e-04
#   -9.27927928e-04  -9.25925926e-04  -9.23923924e-04  -9.21921922e-04
#   -9.19919920e-04  -9.17917918e-04  -9.15915916e-04  -9.13913914e-04
#   -9.11911912e-04  -9.09909910e-04  -9.07907908e-04  -9.05905906e-04
#   -9.03903904e-04  -9.01901902e-04  -8.99899900e-04  -8.97897898e-04
#   -8.95895896e-04  -8.93893894e-04  -8.91891892e-04  -8.89889890e-04
#   -8.87887888e-04  -8.85885886e-04  -8.83883884e-04  -8.81881882e-04
#   -8.79879880e-04  -8.77877878e-04  -8.75875876e-04  -8.73873874e-04
#   -8.71871872e-04  -8.69869870e-04  -8.67867868e-04  -8.65865866e-04
#   -8.63863864e-04  -8.61861862e-04  -8.59859860e-04  -8.57857858e-04
#   -8.55855856e-04  -8.53853854e-04  -8.51851852e-04  -8.49849850e-04
#   -8.47847848e-04  -8.45845846e-04  -8.43843844e-04  -8.41841842e-04
#   -8.39839840e-04  -8.37837838e-04  -8.35835836e-04  -8.33833834e-04
#   -8.31831832e-04  -8.29829830e-04  -8.27827828e-04  -8.25825826e-04
#   -8.23823824e-04  -8.21821822e-04  -8.19819820e-04  -8.17817818e-04
#   -8.15815816e-04  -8.13813814e-04  -8.11811812e-04  -8.09809810e-04
#   -8.07807808e-04  -8.05805806e-04  -8.03803804e-04  -8.01801802e-04
#   -7.99799800e-04  -7.97797798e-04  -7.95795796e-04  -7.93793794e-04
